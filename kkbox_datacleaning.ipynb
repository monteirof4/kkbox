# %%
# Import Dependencies
import glob
import pandas as pd

# %% [markdown]
# # Train DataFrame

# %%
# Import CSV Files
train_filenames = glob.glob('data/*.csv')

# %%
# List Filenames
train_filenames
# Out:
# ['data/songs.csv',
#  'data/test.csv',
#  'data/members.csv',
#  'data/train.csv',
#  'data/song_extra_info.csv']

# %%
# Show Index and Value in list
for i in range(len(train_filenames)): 
    print (i, end = " ") 
    print (train_filenames[i])
# Out:
# 0 data/songs.csv
# 1 data/test.csv
# 2 data/members.csv
# 3 data/train.csv
# 4 data/song_extra_info.csv

# %%
# Remove test.csv, To Create a the Train List
del train_filenames[1]

# %%
# Print Filenames
train_filenames
# Out:
# ['data/songs.csv',
#  'data/members.csv',
#  'data/train.csv',
#  'data/song_extra_info.csv']

# %%
# Create a Train list 
train_list= []

# %%
# Loop and append the csv files
for filename in train_filenames:
    train_list.append(pd.read_csv(filename))

# %%
# Print List
print(train_list)
# Out:
# [                                              song_id  song_length  \
# 0        CXoTN1eb7AI+DntdU1vbcwGRV4SCIDxZu+YD8JP8r4E=       247640
# 1        o0kFgae9QtnYgRkVPqLJwa05zIhRlUjfF7O1tDw0ZDU=       197328
# 2        DwVvVurfpuz+XPuFvucclVQEyPqcpUkHR0ne1RQzPs0=       231781
# 3        dKMBWoZyScdxSkihKG+Vf47nc18N9q4m58+b4e7dSSE=       273554
# 4        W3bqWd3T+VeHFzHAUfARgW9AvVRaF4N5Yzm4Mr6Eo/o=       140329
# 5        kKJ2JNU5h8rphyW21ovC+RZU+yEHPM+3w85J37p7vEQ=       235520
# 6        N9vbanw7BSMoUgdfJlgX1aZPE1XZg8OS1wf88AQEcMc=       226220
# 7        GsCpr618xfveHYJdo+E5SybrpR906tsjLMeKyrCNw8s=       276793
# 8        oTi7oINPX+rxoGp+3O6llSltQTl80jDqHoULfRoLcG4=       228623
# 9        btcG03OHY3GNKWccPP0auvtSbhxog/kllIIOx5grE/k=       232629
# 10       HulM/OaHgD5kUyjNQjDUf8VZdsy7h4EJUIff79Cifwo=       272544
# 11       wypPzqFNdUJAqyBVxmFGaK4z7krUNWr5YqA0q0wi9eE=       254880
# 12       fAZLdfQaLG76a6Ei4alt1eSjBM9rshQkiQEC6+n+y08=       180871
# ...

# %%
# Concatenate all CSV files together in the Train Dataframe
train_df = pd.concat(train_list, sort=False, axis =1)

# %%
# Show Train DataFrame 
train_df.head()
# Out:
#                                         song_id  song_length genre_ids  \
# 0  CXoTN1eb7AI+DntdU1vbcwGRV4SCIDxZu+YD8JP8r4E=     247640.0       465
# 1  o0kFgae9QtnYgRkVPqLJwa05zIhRlUjfF7O1tDw0ZDU=     197328.0       444
# 2  DwVvVurfpuz+XPuFvucclVQEyPqcpUkHR0ne1RQzPs0=     231781.0       465
# 3  dKMBWoZyScdxSkihKG+Vf47nc18N9q4m58+b4e7dSSE=     273554.0       465
# 4  W3bqWd3T+VeHFzHAUfARgW9AvVRaF4N5Yzm4Mr6Eo/o=     140329.0       726
#
#         artist_name                            composer     lyricist  \
# 0  張信哲 (Jeff Chang)                                  董貞          何啟弘
# 1         BLACKPINK  TEDDY|  FUTURE BOUNCE|  Bekuh BOOM        TEDDY
# 2      SUPER JUNIOR                                 NaN          NaN
# 3             S.H.E                                 湯小康          徐世珍
# 4              貴族精選                         Traditional  Traditional
#
#    language                                          msno  city   bd  ...  \
# ...

# %%
# Rename 'msno' column to 'user_id' & 'bd' column to 'age'
train_df.rename(columns={'msno': 'user_id', 'bd': 'age'}, inplace=True)

# %%
# Show Train DataFrame Columns
train_df.columns.tolist()
# Out:
# ['song_id',
#  'song_length',
#  'genre_ids',
#  'artist_name',
#  'composer',
#  'lyricist',
#  'language',
#  'user_id',
#  'city',
#  'age',
#  'gender',
#  'registered_via',
#  'registration_init_time',
#  'expiration_date',
#  'user_id',
#  'song_id',
#  'source_system_tab',
#  'source_screen_name',
#  'source_type',
#  'target',
#  'song_id',
#  'name',
#  'isrc']

# %% [markdown]
# # Test DataFrame

# %%
# Import CSV Files
test_filenames = glob.glob('data/*.csv')

# %%
# List Filenames
test_filenames
# Out:
# ['data/songs.csv',
#  'data/test.csv',
#  'data/members.csv',
#  'data/train.csv',
#  'data/song_extra_info.csv']

# %%
# Show Index and Value in list
for i in range(len(test_filenames)): 
    print (i, end = " ") 
    print (test_filenames[i])
# Out:
# 0 data/songs.csv
# 1 data/test.csv
# 2 data/members.csv
# 3 data/train.csv
# 4 data/song_extra_info.csv

# %%
# Remove train.csv, To Create a the Train List
del test_filenames[3]

# %%
# Print Filenames
test_filenames
# Out:
# ['data/songs.csv',
#  'data/test.csv',
#  'data/members.csv',
#  'data/song_extra_info.csv']

# %%
# Create a Test list 
test_list= []

# %%
# Loop and append the csv files
for filename in test_filenames:
    test_list.append(pd.read_csv(filename))

# %%
# Show Test list
print(test_list)
# Out:
# [                                              song_id  song_length  \
# 0        CXoTN1eb7AI+DntdU1vbcwGRV4SCIDxZu+YD8JP8r4E=       247640
# 1        o0kFgae9QtnYgRkVPqLJwa05zIhRlUjfF7O1tDw0ZDU=       197328
# 2        DwVvVurfpuz+XPuFvucclVQEyPqcpUkHR0ne1RQzPs0=       231781
# 3        dKMBWoZyScdxSkihKG+Vf47nc18N9q4m58+b4e7dSSE=       273554
# 4        W3bqWd3T+VeHFzHAUfARgW9AvVRaF4N5Yzm4Mr6Eo/o=       140329
# 5        kKJ2JNU5h8rphyW21ovC+RZU+yEHPM+3w85J37p7vEQ=       235520
# 6        N9vbanw7BSMoUgdfJlgX1aZPE1XZg8OS1wf88AQEcMc=       226220
# 7        GsCpr618xfveHYJdo+E5SybrpR906tsjLMeKyrCNw8s=       276793
# 8        oTi7oINPX+rxoGp+3O6llSltQTl80jDqHoULfRoLcG4=       228623
# 9        btcG03OHY3GNKWccPP0auvtSbhxog/kllIIOx5grE/k=       232629
# 10       HulM/OaHgD5kUyjNQjDUf8VZdsy7h4EJUIff79Cifwo=       272544
# 11       wypPzqFNdUJAqyBVxmFGaK4z7krUNWr5YqA0q0wi9eE=       254880
# 12       fAZLdfQaLG76a6Ei4alt1eSjBM9rshQkiQEC6+n+y08=       180871
# ...

# %%
# Concatenate all CSV files together in the Test Dataframe
test_df= pd.concat(test_list, sort=False, axis=1)

# %%
# Show Test DataFrame 
test_df.head()
# Out:
#                                         song_id  song_length genre_ids  \
# 0  CXoTN1eb7AI+DntdU1vbcwGRV4SCIDxZu+YD8JP8r4E=     247640.0       465
# 1  o0kFgae9QtnYgRkVPqLJwa05zIhRlUjfF7O1tDw0ZDU=     197328.0       444
# 2  DwVvVurfpuz+XPuFvucclVQEyPqcpUkHR0ne1RQzPs0=     231781.0       465
# 3  dKMBWoZyScdxSkihKG+Vf47nc18N9q4m58+b4e7dSSE=     273554.0       465
# 4  W3bqWd3T+VeHFzHAUfARgW9AvVRaF4N5Yzm4Mr6Eo/o=     140329.0       726
#
#         artist_name                            composer     lyricist  \
# 0  張信哲 (Jeff Chang)                                  董貞          何啟弘
# 1         BLACKPINK  TEDDY|  FUTURE BOUNCE|  Bekuh BOOM        TEDDY
# 2      SUPER JUNIOR                                 NaN          NaN
# 3             S.H.E                                 湯小康          徐世珍
# 4              貴族精選                         Traditional  Traditional
#
#    language  id                                          msno  \
# ...

# %%
# Rename 'msno' column to 'user_id' & 'bd' column to 'age'
test_df.rename(columns={'msno': 'user_id', 'bd': 'age'}, inplace=True)

# %%
# Show Test DataFrame Columns
test_df.columns.tolist()
# Out:
# ['song_id',
#  'song_length',
#  'genre_ids',
#  'artist_name',
#  'composer',
#  'lyricist',
#  'language',
#  'id',
#  'user_id',
#  'song_id',
#  'source_system_tab',
#  'source_screen_name',
#  'source_type',
#  'user_id',
#  'city',
#  'age',
#  'gender',
#  'registered_via',
#  'registration_init_time',
#  'expiration_date',
#  'song_id',
#  'name',
#  'isrc']
